# %% [markdown]
# <a href="https://colab.research.google.com/github/va4756/big_RaeJung/blob/main/choi_guis_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01wk-1: 박스플랏, 히스토그램

# %% [markdown]
# ## 2.Import

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (3, 2) # 가로 6, 세로 4 크기의 그림
matplotlib.rcParams['figure.dpi'] = 150

# %% [markdown]
# ## 3.Boxplot

# %%
# A. motivating example
y1=[75,75,76,76,77,77,78,79,79,98] # A선생님에게 통계학을 배운 학생의 점수들
y2=[76,76,77,77,78,78,79,80,80,81] # B선생님에게 통계학을 배운 학생의 점수들

# %%
np.mean(y1)
# Out:
# np.float64(79.0)

# %%
np.mean(y2)
# Out:
# np.float64(78.2)

# %%
# B. matplotlib으로 boxplot 그리기
plt.boxplot(y1);

# %%
plt.boxplot(y2);

# %%
# A반 학생들의 점수와 B반 학생들의 점수를 나란히 박스플랏으로 그리자.
plt.boxplot([y1, y2]);

# %% [markdown]
# ## 4.Histogram

# %%
np.random.seed(43052)
y1 = np.random.randn(10000)
y2 = np.random.randn(10000) + 0.5

# %%
np.mean(y1), np.mean(y2)
# Out:
# (np.float64(-0.011790879905079434), np.float64(0.4979147460611458))

# %%
np.mean(y2) - np.mean(y1)
# Out:
# np.float64(0.5097056259662253)

# %%
plt.boxplot([y1, y2]);

# %%
#  histogram 그리기
y=[10,11,12,15,16,20,21,22,23,24,25]

# %%
plt.hist(y)
# Out:
# (array([2., 1., 0., 1., 1., 0., 1., 1., 2., 2.]),
#  array([10. , 11.5, 13. , 14.5, 16. , 17.5, 19. , 20.5, 22. , 23.5, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(y, bins=10)
# Out:
# (array([2., 1., 0., 1., 1., 0., 1., 1., 2., 2.]),
#  array([10. , 11.5, 13. , 14.5, 16. , 17.5, 19. , 20.5, 22. , 23.5, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(y, bins=3)
# Out:
# (array([3., 2., 6.]),
#  array([10., 15., 20., 25.]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(y, bins=7, range=[0,30])
# Out:
# (array([0., 0., 3., 2., 2., 4., 0.]),
#  array([ 0.        ,  4.28571429,  8.57142857, 12.85714286, 17.14285714,
#         21.42857143, 25.71428571, 30.        ]),
#  <BarContainer object of 7 artists>)

# %%
# 히스토그램 예시6 – 나란히 그리기
np.random.seed(43052)
y1 = np.random.randn(10000)
y2 = np.random.randn(10000) + 0.5
plt.hist([y1, y2], bins=100);

# %% [markdown]
# ## 5.Histogram equalization

# %% [markdown]
# !wget 주소: 주소에 있는 이미지를 다운로드
#
# !rm 파일이름: 현재폴더에 “파일이름”을 삭제

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/0/08/Unequalized_Hawkes_Bay_NZ.jpg
img = cv2.imread('Unequalized_Hawkes_Bay_NZ.jpg')
# !rm Unequalized_Hawkes_Bay_NZ.jpg
# Out:
# --2026-01-13 09:44:53--  https://upload.wikimedia.org/wikipedia/commons/0/08/Unequalized_Hawkes_Bay_NZ.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.153.240, 2620:0:860:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.153.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 110895 (108K) [image/jpeg]
# Saving to: ‘Unequalized_Hawkes_Bay_NZ.jpg’
#
# Unequalized_Hawkes_ 100%[===================>] 108.30K  --.-KB/s    in 0.1s
#
# 2026-01-13 09:44:53 (1.01 MB/s) - ‘Unequalized_Hawkes_Bay_NZ.jpg’ saved [110895/110895]

# %%
plt.imshow(img)

# %%
# 이미지를 rgb로 각각 분리하고 각 색깔들의 히스토그램을 그려보자.
r = img[:, :, 0]
g = img[:, :, 1]
b = img[:, :, 2]

# %%
plt.hist(r.reshape(-1), range=(0,255), bins=255);

# %%
# cv2.equalizeHist()를 이용하여 분포의 모양은 대략적으로 유지하면서 값을 퍼트리자!
rr = cv2.equalizeHist(r)
gg = cv2.equalizeHist(g)
bb = cv2.equalizeHist(b)

# %%
plt.hist(r.reshape(-1), bins=255, range=[0,255], label='before');
plt.hist(rr.reshape(-1), bins=255, range=[0,255], label='after');
plt.legend();

# %%
img2 = np.stack([rr, gg, bb], axis=-1)

# %%
plt.imshow(img2);

# %%
plt.imshow(np.concatenate([img, img2], axis=1));

# %%
# !wget https://raw.githubusercontent.com/guebin/2021DV/master/_notebooks/hw_img.png
img = cv2.imread('hw_img.png')
# !rm hw_img.png
# Out:
# --2026-01-13 09:44:58--  https://raw.githubusercontent.com/guebin/2021DV/master/_notebooks/hw_img.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 120618 (118K) [image/png]
# Saving to: ‘hw_img.png’
#
# hw_img.png          100%[===================>] 117.79K  --.-KB/s    in 0.02s
#
# 2026-01-13 09:44:58 (4.72 MB/s) - ‘hw_img.png’ saved [120618/120618]

# %%
plt.imshow(img)

# %%
r = img[:, :, 0]
g = img[:, :, 1]
b = img[:, :, 2]

# %%
rr = cv2.equalizeHist(r)
gg = cv2.equalizeHist(g)
bb = cv2.equalizeHist(b)

# %%
img2 = np.stack([rr, gg, bb], axis=-1)

# %%
plt.imshow(np.concatenate([img, img2], axis=1))

# %% [markdown]
# # 01wk-2: 라인플랏, 산점도, 객체지향적 시각화 (1)

# %% [markdown]
# ## 2.Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams['figure.figsize'] = (3, 2)
matplotlib.rcParams['figure.dpi'] = 150

# %% [markdown]
# ## 3.Line plot

# %%
plt.plot([1,2,3,2]);

# %%
plt.plot([1,2,3,2], '--');

# %%
plt.plot([1,2,3,2], '--r');

# %%
plt.plot([1,2,4,3], 'b-..');

# %%
plt.plot([1,2,4,3], 'k:');

# %%
plt.plot([1,2,4,3], color='lime');

# %%
plt.plot([1,2,4,3], color='#7E277E');

# %%
plt.plot([1,2,4,3], linestyle=(0, (10,1)));

# %% [markdown]
# ## 4.Scatter plot

# %%
plt.plot([1,2,4,3], 'x');

# %%
plt.plot([1,2,4,3], 'D');

# %%
plt.plot([1,2,4,3], 'xr');

# %%
plt.plot([1,2,4,3], 'dy');

# %% [markdown]
# ## D. dot-connected plot

# %%
plt.plot([1,2,4,3], '--o');

# %%
plt.plot([1,2,4,3], '--or');

# %%
plt.plot([1,2,4,3], '--o', color='lime');

# %% [markdown]
# ## 5.겹쳐 그리기

# %%
plt.plot([1,2,4,3], '-o')
plt.plot([3,4,1,2], '--o')

# %%
plt.plot([1,2,4,3], color='C0')
plt.plot([3,4,1,2], '--o', color='C1')

# %%
x = np.linspace(0,1,100)
eps = np.random.randn(100) * 0.2
y = 2 * x + eps
plt.plot(x, y, '.');
plt.plot(x, 2*x, '--');

# %% [markdown]
# ## 6.객체지향적 시각화 (1)

# %%
plt.plot([1,2,4,3])
fig = plt.gcf()

# %%
plt.plot([1,2,4,3], '--o');

# %%
fig

# %%
x = np.arange(-5, 5, 0.1)
y1 = np.sin(x)
y2 = np.sin(2*x) + 2
y3 = np.sin(4*x) + 4
y4 = np.sin(8*x) + 8

# %%
plt.figure(figsize=(7,3));
plt.plot(x, y1, 'r--', linewidth=2)
plt.plot(x, y2, 'g--', linewidth=2)
plt.plot(x, y3, 'b--', linewidth=2)
plt.plot(x, y4, 'm--', linewidth=2)

# %%
# 축, 격자 설정
plt.xlim(-5, 5)
plt.ylim(-1.5, 7.5)
plt.grid(True)

# %%
plt.show()

# %% [markdown]
# # 02wk-1: 객체지향적 시각화 (2), Subplot, 산점도 응용예제 1-2

# %% [markdown]
# ## 2.Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
matplotlib.rcParams['figure.figsize'] = (3, 2)
matplotlib.rcParams['figure.dpi'] = 150

# %% [markdown]
# ## 3.객체지향적 시각화 (2)

# %%
plt.plot([1,2,4,3])
fig = plt.gcf()

# %%
plt.plot([1,2,4,3], '--o');

# %%
fig

# %%
fig = plt.Figure()
ax = fig.add_axes([0.125, 0.11, 0.775, 0.77])
ax.set_xlim([-0.15, 3.15])
ax.set_ylim([0.9, 3.1])
line = matplotlib.lines.Line2D(
    xdata = [0,1,2,3],
    ydata = [1,2,3,2],
    linestyle='--',
    marker='o'
)
ax.add_line(line)

fig

# %%
# 조금 다른 방법: Line2d 오브젝트를 쓰지 않는 방법
fig = plt.Figure()
ax = fig.add_axes([0.125, 0.11, 0.775, 0.77])
ax.plot([1,2,3,2], '--o')
fig

# %%
# add_axes()를 쓰지 않는 방법
fig = plt.Figure()
ax = fig.subplots(1)
ax.plot([1,2,3,2], '--o')
fig

# %%
fig, ax = plt.subplots(1)
ax.plot([1,2,3,2], '--o')

# %% [markdown]
# ## D.미니맵

# %%
# fig = plt.Figure()
# ax = fig.add_axes([0,0,2,2])
# ax_mini = fig.add_axes([1.4, 0.2, 0.5, 0.5])
# fig

# %%
# ax.plot([1,5,3,4], '--o')
# ax_mini.plot([1,2,3,1], '--or')
# fig

# %% [markdown]
# ## 6.산점도 응용예제1 – 표본상관계수

# %%
x=[44,48,49,58,62,68,69,70,76,79]  # 몸무게
y=[159,160,162,165,167,162,165,175,165,172]  # 키

# %%
plt.plot(x, y, 'o');

# %%
# (평균을 0으로)
xx = x - np.mean(x)
yy = y - np.mean(y)

# %%
# (퍼진정도를 표준화)
xxx = xx / np.sqrt(np.sum(xx**2))
yyy = yy / np.sqrt(np.sum(yy**2))

# %%
(xxx * yyy).sum()
# Out:
# np.float64(0.7138620583559141)

# %%
# 상관계수를 계산하는 방법2
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.71386206],
#        [0.71386206, 1.        ]])

# %%
# 아래의 그림은 상관계수 의 값이 양수인가 음수인가?
xx = x - np.mean(x)
yy = y - np.mean(y)
xxx = xx / np.sqrt(np.sum(xx ** 2))
yyy = yy / np.sqrt(np.sum(yy ** 2))

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10,3))
ax1.plot(x,y,'o'); ax1.set_title(r'$(x_i, y_i)$')
ax2.plot(xx,yy,'o'); ax2.set_title(r'$(x_i-\bar{x}, y_i-\bar{y})$')
ax3.plot(xxx,yyy,'o'); ax3.set_title(r'$(\tilde{x}_i, \tilde{y}_i)$')
# Out:
# Text(0.5, 1.0, '$(\\tilde{x}_i, \\tilde{y}_i)$')

# %% [markdown]
# ## D.산점도를 보고 상관계수의 절대값을 해석

# %%
x = np.arange(0, 10, 0.1)
y1 = x + np.random.normal(loc=0, scale=1.0, size=len(x))
y2 = x + np.random.normal(loc=0, scale=7.0, size=len(x))

plt.plot(x, y1, '.')
plt.plot(x, y2, 'x')

# %%
def tilde(x):
    xx = x - np.mean(x)
    xxx = xx / np.sqrt(np.sum(xx ** 2))
    return xxx

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(4,2))
ax1.plot(x, y1, '.'); ax1.plot(x, y2, 'x'); ax1.set_title(r'$(x_i, y_i)$')
ax2.plot(tilde(x), tilde(y1), '.'); ax2.plot(tilde(x), tilde(y2), 'x'); ax2.set_title(r'$(\tilde{x}_i, \tilde{y}_i)$')
fig.tight_layout()

# %% [markdown]
# ## 7. 산점도 응용예제2 – 앤스콤의 4분할

# %%
x1 = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]

x2 = x1
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]

x3 = x1
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]

x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
np.corrcoef([x1,y1]), np.corrcoef([x2, y2]), np.corrcoef([x3, y3]), np.corrcoef([x4, y4])
# Out:
# (array([[1.        , 0.81642052],
#         [0.81642052, 1.        ]]),
#  array([[1.        , 0.81623651],
#         [0.81623651, 1.        ]]),
#  array([[1.        , 0.81628674],
#         [0.81628674, 1.        ]]),
#  array([[1.        , 0.81652144],
#         [0.81652144, 1.        ]]))

# %%
# 교훈1: 데이터를 분석하기 전에 항상 시각화를 하라.
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(6, 4))
ax1.plot(x1,y1, 'o'); ax1.set_title('corrcoef= 0.81642052')
ax2.plot(x2,y2, 'o'); ax2.set_title('corrcoef= 0.81642052')
ax3.plot(x3,y3,'o'); ax3.set_title('corrcoef= 0.81628674')
ax4.plot(x4,y4,'o'); ax4.set_title('corrcoef= 0.81652144')

fig.tight_layout()

# %%
plt.plot(x1, y1, 'x')

# %%
plt.plot(x1+[99], y1+[-99], 'x')

# %% [markdown]
# # 02wk-2: Seaborn 간략한 소개, 훌륭한 시각화(1)

# %% [markdown]
# ## 2. Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['figure.dpi'] = 120

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guebin/DV2023/main/posts/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   logFare
# 0      0         A/5 21171   7.2500   NaN        S  1.981001
# 1      0          PC 17599  71.2833   C85        C  4.266662
# 2      0  STON/O2. 3101282   7.9250   NaN        S  2.070022
# 3      0            113803  53.1000  C123        S  3.972177
# 4      0            373450   8.0500   NaN        S  2.085672

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'logFare'],
#       dtype='object')

# %%
sns.scatterplot(
    df,
    x = 'logFare',
    y = 'Age',
    hue = 'Sex',
    style='Survived', style_order=[1,0],
    alpha = 0.8
);

# %%
plt.hist(df.Age)
plt.hist(df.Age[df.Survived==1]);

# %%
sns.scatterplot(
    df,
    x = 'logFare',
    y = 'Age',
    hue = 'Sex',
    style='Survived', style_order=[1,0],
    alpha = 0.8
)
fig = plt.gcf()
ax = plt.gca()
ax.set_title('Scatter Plot')
fig.add_axes([0.6, 0.2, 0.25, 0.25])
ax_mini = plt.gca()
ax_mini.hist(df.Age)
ax_mini.hist(df.Age[df.Survived==1])
ax_mini.set_title('Histogram')

fig.suptitle('TITANIC')
# Out:
# Text(0.5, 0.98, 'TITANIC')

# %% [markdown]
# ## C. 미나드처럼 그리는게 왜 어려운가?

# %%
# 몸무게, 키, 성별, 국적
df1=pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/male1.csv')
df2=pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/male2.csv')
df3=pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/female.csv')
df4=pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/foreign.csv')

# %%
df1.head(), df2.head(), df3.head(), df4.head()
# Out:
# (           w
#  0  72.788217
#  1  66.606430
#  2  69.806324
#  3  67.449439
#  4  70.463183,
#              h
#  0  183.486773
#  1  173.599877
#  2  173.237903
#  3  173.223805
#  4  174.931946,
#             w           h
#  0  50.832743  157.144482
#  1  49.767618  160.784478
#  2  47.930381  159.044675
#  3  49.200626  157.992591
#  4  51.045006  163.078925,
#             w           h  g
#  0  94.033546  195.297789  m
#  1  84.139393  189.289647  m
#  2  75.860293  185.265391  f
#  3  87.412981  189.631678  m
#  4  84.935675  187.196177  m)

# %%
# 미나드의 접근방법
_df = pd.concat([pd.concat([df1, df2], axis=1).assign(g='m'), df3.assign(g='f')])
df = pd.concat([_df.assign(g2='korea'), df4.assign(g2='foreign')]).reset_index(drop=True)
df
# Out:
#               w           h  g       g2
# 0     72.788217  183.486773  m    korea
# 1     66.606430  173.599877  m    korea
# 2     69.806324  173.237903  m    korea
# 3     67.449439  173.223805  m    korea
# 4     70.463183  174.931946  m    korea
# ...         ...         ... ..      ...
# 1525  78.154632  188.324350  m  foreign
# 1526  74.754308  183.017979  f  foreign
# 1527  91.196208  190.100456  m  foreign
# 1528  87.770394  187.987255  m  foreign
# 1529  88.021995  193.456798  m  foreign
#
# [1530 rows x 4 columns]

# %%
sns.scatterplot(
    data=df,
    x='w',
    y='h',
    hue='g',
    style='g2'
);

# %% [markdown]
# # 03wk-1: mpg data, 아이스크림을 많이 먹으면 걸리는 병

# %% [markdown]
# ## 2. Imports

# %%
# !pip install plotnine
# Out:
# Requirement already satisfied: plotnine in /usr/local/lib/python3.12/dist-packages (0.14.5)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from plotnine) (3.10.0)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from plotnine) (2.2.2)
# Requirement already satisfied: mizani~=0.13.0 in /usr/local/lib/python3.12/dist-packages (from plotnine) (0.13.5)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from plotnine) (2.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from plotnine) (1.16.3)
# Requirement already satisfied: statsmodels>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from plotnine) (0.14.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8.0->plotnine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->plotnine) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->plotnine) (2025.3)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.0->plotnine) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->plotnine) (1.17.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from plotnine import *

# %%
import plotnine
