# %% [markdown]
# <a href="https://colab.research.google.com/github/va4756/big_RaeJung/blob/main/bigdata_statistics_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/leeraejung/RaejungLecture-VisualPython2025
# Out:
# fatal: destination path 'RaejungLecture-VisualPython2025' already exists and is not an empty directory.

# %% [markdown]
# # 102_Descriptive_Statistics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'NanumBarunGothic'
rcParams['font.size'] = 10
rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 1.Descriptive Statistics (기술 통계)

# %%
df = pd.read_csv('/content/RaejungLecture-VisualPython2025/04_Statistics/data/02_1_기술통계.csv',
                 index_col=0)
print(df.shape)
df.head()
# Out:
# (100, 4)
#     성별  학력  언어점수  수리점수
# id
# 1   여자  대졸  53.0  76.0
# 2   남자  고졸  66.0  62.0
# 3   여자  고졸  60.0  59.0
# 4   남자  고졸  87.5  73.0
# 5   여자  대졸  57.0  89.0

# %%
vp_df = df.copy()

# Descriptive statistics
from IPython.display import display, Markdown
display(Markdown('**Descriptive Statistics**'))
display(vp_df.describe().T)
# Out:
# **Descriptive Statistics**
#       count     mean        std    min     25%     50%    75%    max
# 언어점수  100.0  69.5850  17.349796  15.00  60.000  70.000  85.00  97.50
# 수리점수  100.0  68.1654  17.063563  23.33  56.045  69.165  84.17  95.83

# %%
display(pd.DataFrame({
    'N Total':vp_df.shape[0],
    'N Valid':vp_df.count(numeric_only=True),
    'N Missing':vp_df.loc[:,vp_df.apply(pd.api.types.is_numeric_dtype)].isnull().sum(),
    'Mean':vp_df.mean(numeric_only=True),
    'Sum':vp_df.sum(numeric_only=True),
    'Std. deviation':vp_df.std(numeric_only=True),
    'Percentile: 25':vp_df.quantile(q=0.25, numeric_only=True),
    'Percentile: 50':vp_df.quantile(q=0.50, numeric_only=True),
    'Percentile: 75':vp_df.quantile(q=0.75, numeric_only=True),
}).round(3).T)
# Out:
#                     언어점수      수리점수
# N Total          100.000   100.000
# N Valid          100.000   100.000
# N Missing          0.000     0.000
# Mean              69.585    68.165
# Sum             6958.500  6816.540
# Std. deviation    17.350    17.064
# Percentile: 25    60.000    56.045
# Percentile: 50    70.000    69.165
# Percentile: 75    85.000    84.170

# %%
# Frequency table
display(Markdown('### Frequency table'))
# Out:
# ### Frequency table
